# %% [markdown]
# # Exploratory Data Analysis
#
# In this assignment we will work with data about the Titanic's passengers.
#
# Objectives:
# * to familiarize you with the seaborn library
# * learn how to build different visualizations
# * fill the gaps in the data
# * encode categorical data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Let's load the data.

# %%
df = pd.read_csv("titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 886        887.0       0.0     2.0
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    male  22.0    1.0
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen; Miss. Laina  female  26.0    0.0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                             Allen; Mr. William Henry    male  35.0    0.0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila; Rev. Juozas    male  27.0    0.0
# 887                       Graham; Miss. Margaret Edith  female  19.0    0.0
# 888           Johnston; Miss. Catherine Helen "Carrie"  female   NaN    1.0
# 889                              Behr; Mr. Karl Howell    male  26.0    0.0
# 890                                Dooley; Mr. Patrick    male  32.0    0.0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0      0.0         A/5 21171   7.2500   NaN        S
# 1      0.0          PC 17599  71.2833   C85        C
# 2      0.0  STON/O2. 3101282   7.9250   NaN        S
# 3      0.0            113803  53.1000  C123        S
# 4      0.0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886    0.0            211536  13.0000   NaN        S
# 887    0.0            112053  30.0000   B42        S
# 888    2.0        W./C. 6607  23.4500   NaN        S
# 889    0.0            111369  30.0000  C148        C
# 890    0.0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Task 1
# Display the first 7 rows of the table and the table dimensions.

# %%
print(df.head(7))
print(df.isna().sum()) #summing the NaN values
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
# 5          NaN       NaN     NaN
# 6          7.0       0.0     1.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund; Mr. Owen Harris    male  22.0    1.0
# 1  Cumings; Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen; Miss. Laina  female  26.0    0.0
# 3       Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen; Mr. William Henry    male  35.0    0.0
# 5                                                NaN     NaN   NaN    NaN
# 6                            McCarthy; Mr. Timothy J    male  54.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171   7.2500   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3    0.0            113803  53.1000  C123        S
# 4    0.0            373450   8.0500   NaN        S
# 5    NaN               NaN      NaN   NaN      NaN
# 6    0.0             17463  51.8625   E46        S
# PassengerId      5
# Survived         5
# Pclass           5
# Name             5
# Sex              5
# Age            180
# SibSp            5
# Parch            5
# Ticket           5
# Fare             5
# Cabin          687
# Embarked         7
# dtype: int64

# %% [markdown]
# # Feature Processing
#
# 1) Find columns that have missing values and process these missing values
#
# 2) Translate categorical features into numerical

# %% [markdown]
# ### Task 2
# Output the basic numerical characteristics of the numerical columns. The method `.describe()` can be very usefull here.

# %%
df.describe() #I dont understand what the exact task is?
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   886.000000  886.000000  886.000000  711.000000  886.000000
# mean    448.316027    0.383747    2.305869   29.743094    0.523702
# std     256.211467    0.486572    0.837071   14.505873    1.105202
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     227.250000    0.000000    2.000000   20.750000    0.000000
# 50%     448.500000    0.000000    3.000000   28.000000    0.000000
# 75%     669.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  886.000000  886.000000
# mean     0.375847   32.279387
# std      0.791082   49.817969
# min      0.000000    0.000000
# 25%      0.000000    7.903100
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# The function does not allow you to see if there are missing values in non-numeric columns.
#
# ## Process the 'Sex' column
#
# ### Task 3
# Check if there are missing values in the column.

# %%
total = df.Sex.isna().sum()
print("sum = ", total)
# Out:
# sum =  5

# %% [markdown]
# ### Task 4
# You should get 5 in the previous taks. It is a very small amount. Therefore, we can remove them completely from the dataset. Do it.

# %%
missing_value_index = np.where(df.Sex.isna())[0]
df = df.drop(index=missing_value_index)
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 886        887.0       0.0     2.0
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    male  22.0    1.0
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen; Miss. Laina  female  26.0    0.0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                             Allen; Mr. William Henry    male  35.0    0.0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila; Rev. Juozas    male  27.0    0.0
# 887                       Graham; Miss. Margaret Edith  female  19.0    0.0
# 888           Johnston; Miss. Catherine Helen "Carrie"  female   NaN    1.0
# 889                              Behr; Mr. Karl Howell    male  26.0    0.0
# 890                                Dooley; Mr. Patrick    male  32.0    0.0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0      0.0         A/5 21171   7.2500   NaN        S
# 1      0.0          PC 17599  71.2833   C85        C
# 2      0.0  STON/O2. 3101282   7.9250   NaN        S
# 3      0.0            113803  53.1000  C123        S
# 4      0.0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886    0.0            211536  13.0000   NaN        S
# 887    0.0            112053  30.0000   B42        S
# 888    2.0        W./C. 6607  23.4500   NaN        S
# 889    0.0            111369  30.0000  C148        C
# 890    0.0            370376   7.7500   NaN        Q
#
# [886 rows x 12 columns]

# %% [markdown]
# The `Sex` feature is categorical, i.e. it contains non-numeric values. For most algorithms to work, it is necessary to map categories into numbers. How can this be done?
#
# ### Task 5
# Encode the categorical features with any method. For example, you can values to 0 and 1, since this feature is binary (the function `.replace` does it).

# %%
#lets say male = 1 and female = 0 
#use replace function to change data types

# %%
df = df.replace({"male" : 1,"female" : 0})
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 886        887.0       0.0     2.0
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    1  22.0    1.0
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...    0  38.0    1.0
# 2                               Heikkinen; Miss. Laina    0  26.0    0.0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)    0  35.0    1.0
# 4                             Allen; Mr. William Henry    1  35.0    0.0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila; Rev. Juozas    1  27.0    0.0
# 887                       Graham; Miss. Margaret Edith    0  19.0    0.0
# 888           Johnston; Miss. Catherine Helen "Carrie"    0   NaN    1.0
# 889                              Behr; Mr. Karl Howell    1  26.0    0.0
# 890                                Dooley; Mr. Patrick    1  32.0    0.0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0      0.0         A/5 21171   7.2500   NaN        S
# 1      0.0          PC 17599  71.2833   C85        C
# 2      0.0  STON/O2. 3101282   7.9250   NaN        S
# 3      0.0            113803  53.1000  C123        S
# 4      0.0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886    0.0            211536  13.0000   NaN        S
# 887    0.0            112053  30.0000   B42        S
# 888    2.0        W./C. 6607  23.4500   NaN        S
# 889    0.0            111369  30.0000  C148        C
# 890    0.0            370376   7.7500   NaN        Q
#
# [886 rows x 12 columns]
# /tmp/ipykernel_4405/3732244547.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({"male" : 1,"female" : 0})

# %% [markdown]
# Let's see how gender affects survival rates.

# %%
sns.barplot(x='Sex', y='Survived', data=df, palette='summer')
plt.title('Sex - Survived')
plt.show()
# Out:
# /tmp/ipykernel_4405/1855343822.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Sex', y='Survived', data=df, palette='summer')

# %% [markdown]
# Let's see how a person's gender and ticket class (Pclass) affect survival rates

# %%
sns.barplot(x='Sex', y='Survived', hue='Pclass', data=df, palette='autumn')
plt.title('Sex - Survived')
plt.show()

# %% [markdown]
# Another useful type of visualization is the box plot box. Let's look at a box plot that reflects the distribution of passengers by gender and age.

# %%
sns.catplot(x="Sex", y="Age", data=df, kind="box")
plt.show()

# %% [markdown]
# We can detail the picture by adding Pclass separation.

# %%
sns.catplot(x="Sex", y="Age",hue ="Pclass", data=df, kind="box")
plt.show()

# %% [markdown]
# ## Process the 'Embarked' feature

# %%
print(df['Embarked'].value_counts(dropna=False))
df.shape
# Out:
# Embarked
# S      641
# C      168
# Q       75
# NaN      2
# Name: count, dtype: int64
# (886, 12)

# %% [markdown]
# ### Task 6
# Remove passengers from the table for whom the port of embarkation (Embarked) is unknown.

# %%
print(df['Embarked'].value_counts(dropna=True))
df.shape
# Out:
# Embarked
# S    641
# C    168
# Q     75
# Name: count, dtype: int64
# (886, 12)

# %% [markdown]
# Let's convert the categorical column to numeric columns using One-Hot Encoding, namely, create three numeric columns as follows:

# %%
df['EmbS'] = df.apply(lambda row: 1 if row.Embarked == 'S' else 0, axis=1)
df['EmbC'] = df.apply(lambda row: 1 if row.Embarked == 'C' else 0, axis=1)
df['EmbQ'] = df.apply(lambda row: 1 if row.Embarked == 'Q' else 0, axis=1)

# %% [markdown]
# This operation can be done using the `get_dummies` method.

# %%
pd.get_dummies(df['Embarked'])
# Out:
#          C      Q      S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 886  False  False   True
# 887  False  False   True
# 888  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [886 rows x 3 columns]

# %% [markdown]
# ### Task 7
# Remove the categorical column `Embarked` from the table and add new columns to it, obtained using `get_dummies`.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 886        887.0       0.0     2.0
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    1  22.0    1.0
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...    0  38.0    1.0
# 2                               Heikkinen; Miss. Laina    0  26.0    0.0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)    0  35.0    1.0
# 4                             Allen; Mr. William Henry    1  35.0    0.0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila; Rev. Juozas    1  27.0    0.0
# 887                       Graham; Miss. Margaret Edith    0  19.0    0.0
# 888           Johnston; Miss. Catherine Helen "Carrie"    0   NaN    1.0
# 889                              Behr; Mr. Karl Howell    1  26.0    0.0
# 890                                Dooley; Mr. Patrick    1  32.0    0.0
#
#      Parch            Ticket     Fare Cabin Embarked  EmbS  EmbC  EmbQ
# 0      0.0         A/5 21171   7.2500   NaN        S     1     0     0
# 1      0.0          PC 17599  71.2833   C85        C     0     1     0
# 2      0.0  STON/O2. 3101282   7.9250   NaN        S     1     0     0
# 3      0.0            113803  53.1000  C123        S     1     0     0
# 4      0.0            373450   8.0500   NaN        S     1     0     0
# ..     ...               ...      ...   ...      ...   ...   ...   ...
# 886    0.0            211536  13.0000   NaN        S     1     0     0
# 887    0.0            112053  30.0000   B42        S     1     0     0
# 888    2.0        W./C. 6607  23.4500   NaN        S     1     0     0
# 889    0.0            111369  30.0000  C148        C     0     1     0
# 890    0.0            370376   7.7500   NaN        Q     0     0     1
#
# [886 rows x 15 columns]

# %%
df_encoded = pd.get_dummies(df['Embarked'])
df_encoded
# Out:
#          C      Q      S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 886  False  False   True
# 887  False  False   True
# 888  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [886 rows x 3 columns]

# %%
df[df_encoded.columns] = df_encoded

# %%
df = df.drop(labels='Embarked', axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 886        887.0       0.0     2.0
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    1  22.0    1.0
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...    0  38.0    1.0
# 2                               Heikkinen; Miss. Laina    0  26.0    0.0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)    0  35.0    1.0
# 4                             Allen; Mr. William Henry    1  35.0    0.0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila; Rev. Juozas    1  27.0    0.0
# 887                       Graham; Miss. Margaret Edith    0  19.0    0.0
# 888           Johnston; Miss. Catherine Helen "Carrie"    0   NaN    1.0
# 889                              Behr; Mr. Karl Howell    1  26.0    0.0
# 890                                Dooley; Mr. Patrick    1  32.0    0.0
#
#      Parch            Ticket     Fare Cabin  EmbS  EmbC  EmbQ      C      Q  \
# 0      0.0         A/5 21171   7.2500   NaN     1     0     0  False  False
# 1      0.0          PC 17599  71.2833   C85     0     1     0   True  False
# 2      0.0  STON/O2. 3101282   7.9250   NaN     1     0     0  False  False
# 3      0.0            113803  53.1000  C123     1     0     0  False  False
# 4      0.0            373450   8.0500   NaN     1     0     0  False  False
# ..     ...               ...      ...   ...   ...   ...   ...    ...    ...
# 886    0.0            211536  13.0000   NaN     1     0     0  False  False
# 887    0.0            112053  30.0000   B42     1     0     0  False  False
# 888    2.0        W./C. 6607  23.4500   NaN     1     0     0  False  False
# 889    0.0            111369  30.0000  C148     0     1     0   True  False
# 890    0.0            370376   7.7500   NaN     0     0     1  False   True
#
#          S
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# ..     ...
# 886   True
# 887   True
# 888   True
# 889  False
# 890  False
#
# [886 rows x 17 columns]

# %% [markdown]
# ## Process the 'Age' feature
#
# Check if `Age` has any missing values.

# %%
df.Age.isna().sum()
# Out:
# 175

# %% [markdown]
# Let's fill in the blanks with the median `Age` value.

# %%
median_age = df['Age'].median()

df['Age'].fillna(median_age, inplace=True)
# Out:
# /tmp/ipykernel_4405/959861609.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(median_age, inplace=True)

# %% [markdown]
# Let's plot the age distribution of the passengers.

# %%
sns.displot(df['Age'], kde=False)
plt.show()

# %% [markdown]
# We can also look at the age distribution of `Pclass`.

# %%
import seaborn as sns

facet = sns.FacetGrid(data=df, hue="Pclass", legend_out=True)
facet = facet.map(sns.kdeplot, "Age")
facet.add_legend()

# %% [markdown]
# ### Process the 'Fare' feature
#
# 1) Check if there are any missing values in `Fare`
#
# 2) If there are missing values, fill them with the _median_ value of `Fare`

# %%
df.Fare.isna().sum()

median_age = df['Age'].median()

df['Age'].fillna(median_age, inplace=True)
df
# Out:
# /tmp/ipykernel_4405/1385323163.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(median_age, inplace=True)
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 886        887.0       0.0     2.0
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund; Mr. Owen Harris    1  22.0    1.0
# 1    Cumings; Mrs. John Bradley (Florence Briggs Th...    0  38.0    1.0
# 2                               Heikkinen; Miss. Laina    0  26.0    0.0
# 3         Futrelle; Mrs. Jacques Heath (Lily May Peel)    0  35.0    1.0
# 4                             Allen; Mr. William Henry    1  35.0    0.0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila; Rev. Juozas    1  27.0    0.0
# 887                       Graham; Miss. Margaret Edith    0  19.0    0.0
# 888           Johnston; Miss. Catherine Helen "Carrie"    0  28.0    1.0
# 889                              Behr; Mr. Karl Howell    1  26.0    0.0
# 890                                Dooley; Mr. Patrick    1  32.0    0.0
#
#      Parch            Ticket     Fare Cabin  EmbS  EmbC  EmbQ      C      Q  \
# 0      0.0         A/5 21171   7.2500   NaN     1     0     0  False  False
# 1      0.0          PC 17599  71.2833   C85     0     1     0   True  False
# 2      0.0  STON/O2. 3101282   7.9250   NaN     1     0     0  False  False
# 3      0.0            113803  53.1000  C123     1     0     0  False  False
# 4      0.0            373450   8.0500   NaN     1     0     0  False  False
# ..     ...               ...      ...   ...   ...   ...   ...    ...    ...
# 886    0.0            211536  13.0000   NaN     1     0     0  False  False
# 887    0.0            112053  30.0000   B42     1     0     0  False  False
# 888    2.0        W./C. 6607  23.4500   NaN     1     0     0  False  False
# 889    0.0            111369  30.0000  C148     0     1     0   True  False
# 890    0.0            370376   7.7500   NaN     0     0     1  False   True
#
#          S
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# ..     ...
# 886   True
# 887   True
# 888   True
# 889  False
# 890  False
#
# [886 rows x 17 columns]

# %% [markdown]
# ### Process the 'Pclass' feature
#
# Are there any missing values in `Pclass`?

# %%
df['Pclass'].value_counts(dropna=False)
# Out:
# Pclass
# 3.0    487
# 1.0    216
# 2.0    183
# Name: count, dtype: int64

# %% [markdown]
# ### Task 8
# Draw a histogram of survival rates as a function of `Pclass`.

# %%
sns.displot(df['Pclass'], kde=False)
plt.show()

# %% [markdown]
# ### Process the feature 'SibSp' (number of siblings, husbands, wives)
#
# Are there any missing values in `SibSp`?

# %%
df.SibSp.isna().sum()
#ANSWER: No
df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0         0.0     3.0                            Braund; Mr. Owen Harris    1
# 1         1.0     1.0  Cumings; Mrs. John Bradley (Florence Briggs Th...    0
# 2         1.0     3.0                             Heikkinen; Miss. Laina    0
# 3         1.0     1.0       Futrelle; Mrs. Jacques Heath (Lily May Peel)    0
# 4         0.0     3.0                           Allen; Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 886       0.0     2.0                              Montvila; Rev. Juozas    1
# 887       1.0     1.0                       Graham; Miss. Margaret Edith    0
# 888       0.0     3.0           Johnston; Miss. Catherine Helen "Carrie"    0
# 889       1.0     1.0                              Behr; Mr. Karl Howell    1
# 890       0.0     3.0                                Dooley; Mr. Patrick    1
#
#       Age  SibSp  Parch            Ticket     Fare Cabin  EmbS  EmbC  EmbQ  \
# 0    22.0    1.0    0.0         A/5 21171   7.2500   NaN     1     0     0
# 1    38.0    1.0    0.0          PC 17599  71.2833   C85     0     1     0
# 2    26.0    0.0    0.0  STON/O2. 3101282   7.9250   NaN     1     0     0
# 3    35.0    1.0    0.0            113803  53.1000  C123     1     0     0
# 4    35.0    0.0    0.0            373450   8.0500   NaN     1     0     0
# ..    ...    ...    ...               ...      ...   ...   ...   ...   ...
# 886  27.0    0.0    0.0            211536  13.0000   NaN     1     0     0
# 887  19.0    0.0    0.0            112053  30.0000   B42     1     0     0
# 888  28.0    1.0    2.0        W./C. 6607  23.4500   NaN     1     0     0
# 889  26.0    0.0    0.0            111369  30.0000  C148     0     1     0
# 890  32.0    0.0    0.0            370376   7.7500   NaN     0     0     1
#
#          C      Q      S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 886  False  False   True
# 887  False  False   True
# 888  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [886 rows x 16 columns]

# %% [markdown]
# ### Task 9
# The `PassengerId` column is categorical and does not carry important information, delete it.

# %%
df = df.drop(labels='PassengerId', axis=1)
#removed from previous question
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[294], line 1
# ----> 1 df = df.drop(labels='PassengerId', axis=1)
#       2 #removed from previous question
#
# File ~/miniconda3/envs/condaenv/lib/python3.12/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File ~/miniconda3/envs/condaenv/lib/python3.12/site-packages/pandas/core/generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File ~/miniconda3/envs/condaenv/lib/python3.12/site-packages/pandas/core/generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File ~/miniconda3/envs/condaenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['PassengerId'] not found in axis"
